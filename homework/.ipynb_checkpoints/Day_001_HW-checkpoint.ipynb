# %% [markdown]
# <作業一>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = 0.5 * np.sum((y - yp)**2)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 10939.186
# The Mean absolute error is 11.968

# %% [markdown]
# <作業二>
# Competition:Flower Classification with TPUs(Use TPUs to classify 104 types of flowers)
#
# 1.你選的這組資料為何重要
# Ans:我希望可以學習ML在影像上的應用，我認為這組dataset是很好的入門資料。
#
# 2.資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# Ans:From 5 datasets: ImageNet, Oxford 102 Category Flowers, TF Flowers, Open Images, and iNaturalist.
#
# 3.蒐集而來的資料型態為何
# Ans:不同圖片尺寸資料夾內，有test&train資料夾，裡面包含圖片id, label,img等資料
#
# 4.這組資料想解決的問題如何評估
# Ans:用包含train資料夾內的label、img進行training，並用test data驗證accuracy

# %% [markdown]
# <作業三>
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# Ans:提升業績代表提高載客頻率&為公司提升收入，故應找出各縣市的那些區域要較高載客率，以及是否有哪些舉辦的活動會影響載客率
#
# 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# Ans:可由載客車上GPS定位載客位置，車上里程讀表機取得載客消費金額及里程。
#
# 蒐集而來的資料型態為何
# Ans:str、int
#
# 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# Ans:改變客車停等載客位置，是否帶來公司收入提升
